# %% [markdown]
# ## 5. Further Analysis

# %% [markdown]
# #### For this task, you need to further explore the given dataset on your own by using different analysis and visualization techniques and then present the insights that you have gained. Be creative and come up with interesting insights and draw conclusions from the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('student.csv')
data.head(3)
# Out:
#   school sex  age address famsize Pstatus                           Medu  \
# 0     GP   F   18       U     GT3       A               higher education
# 1     GP   F   17       U     GT3       T  primary education (4th grade)
# 2     GP   F   15       U     LE3       T  primary education (4th grade)
#
#                             Fedu     Mjob     Fjob  ...     famrel freetime  \
# 0               higher education  at_home  teacher  ...  very good   medium
# 1  primary education (4th grade)  at_home    other  ...  excellent   medium
# 2  primary education (4th grade)  at_home    other  ...  very good   medium
#
#     goout      Dalc      Walc health absences G1 G2  G3
# 0    high  very low  very low   good        6  5  6   6
# 1  medium  very low  very low   good        4  5  5   6
# 2     low       low    medium   good       10  7  8  10
#
# [3 rows x 33 columns]

# %%
plt.pie(data.groupby('school')['school'].count(),
labels=['Gabriel Pereira', 'Mousinho da Silveira'],
colors=["#66cc99", "#ffff66"],
autopct="%.1f%%",
)
plt.title("Pie-chart representing number of Students by School")
# Out:
# Text(0.5, 1.0, 'Pie-chart representing number of Students by School')

# %%
maleStudents = data[data['sex']== 'M'].groupby('school')['sex'].count()
maleStudents
# Out:
# school
# GP    166
# MS     21
# Name: sex, dtype: int64

# %%
dictMaleStudents = {}
keyCount = 0
for i in maleStudents.index:
    dictMaleStudents[keyCount] = maleStudents[i]
    keyCount += 1
dictMaleStudents
# Out:
# {0: 166, 1: 21}

# %%
femaleStudents = data[data['sex']== 'F'].groupby('school')['sex'].count()
femaleStudents
# Out:
# school
# GP    183
# MS     25
# Name: sex, dtype: int64

# %%
dictFemaleStudents = {}
keyCount = 0
for i in femaleStudents.index:
    dictFemaleStudents[keyCount] = femaleStudents[i]
    keyCount += 1
dictFemaleStudents
# Out:
# {0: 183, 1: 25}

# %%
plt.figure(figsize=(10,6))
plt.bar(np.array(list(dictMaleStudents.keys())),
np.array(list(dictMaleStudents.values())),
color="#3399ff",
width=0.25,
label = 'Male'
)

plt.bar(np.array(list(dictFemaleStudents.keys()))+0.25,
np.array(list(dictFemaleStudents.values())),
color="#ffccff",
width=0.25,
label = 'Female'
)
plt.title("Bar graph of total number of male and female students by school")
plt.xlabel("School")
plt.ylabel ("Number of Students")
plt.xticks (np.array(list (dictMaleStudents.keys ())).astype("int64" )+0.12,
['Gabriel Pereira', 'Mousinho da Silveira'])
plt.legend()

# %%
educational_support_finals = sns.catplot(x = 'schoolsup', y = 'G3', data= data, hue = 'sex', kind='swarm')
# Out:
# /Users/kushalrajbhandari/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 22.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
school_wise_performance = sns.catplot(x = 'school', y = 'G3', data= data, kind='box')
